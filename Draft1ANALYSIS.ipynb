# %%
import pandas as pd
import numpy as np
import os

#---------ANALYSIS OF DIFFICULTY----------

df = pd.read_csv('Comparison2.csv')
#read Session 2 Comparison Questionnaire CSV file, raw data


#to read column headers use print(comparison2.columns)

df.describe()
#Statistical summary of User-study Session 2 responses from participants after using the software
# Out:
#        Difficulty_Wizard  Difficulty_QuickForm  Difficulty_WebProtege  \
# count          28.000000             28.000000              28.000000
# mean            2.142857              1.178571               2.928571
# std             0.705234              0.390021               0.662687
# min             1.000000              1.000000               1.000000
# 25%             2.000000              1.000000               3.000000
# 50%             2.000000              1.000000               3.000000
# 75%             2.250000              1.000000               3.000000
# max             4.000000              2.000000               4.000000
#
#        Difficulty_WikiData   RankDiff  ExpDiff  Helpfulness_Wizard  \
# count            28.000000  28.000000      0.0           28.000000
# mean              3.750000   1.464286      NaN            2.142857
# std               0.585314   0.507875      NaN            1.044005
# min               2.000000   1.000000      NaN            1.000000
# 25%               4.000000   1.000000      NaN            1.000000
# 50%               4.000000   1.000000      NaN            2.000000
# 75%               4.000000   2.000000      NaN            3.000000
# max               4.000000   2.000000      NaN            4.000000
#
#        Helpfulness_QuickForm  Helpfulness_WebProtege  Helpfulness_Wiki  \
# count              28.000000               28.000000         28.000000
# mean                2.642857                2.642857          2.571429
# std                 1.311326                0.951190          1.136224
# min                 1.000000                1.000000          1.000000
# 25%                 1.000000                2.000000          2.000000
# 50%                 2.500000                3.000000          2.500000
# 75%                 4.000000                3.000000          4.000000
# max                 4.000000                4.000000          4.000000
#
#        RankHelpfulness  ExpHelpfulness  Confdence_Wizard  \
# count        28.000000             0.0         28.000000
# mean          1.785714             NaN          3.714286
# std           0.568112             NaN          1.013141
# min           1.000000             NaN          2.000000
# 25%           1.000000             NaN          3.000000
# 50%           2.000000             NaN          4.000000
# 75%           2.000000             NaN          4.250000
# max           3.000000             NaN          5.000000
#
#        Confidence_QuickForm  Confidence_WebProtege  Confidence_WikiData
# count             28.000000              28.000000            28.000000
# mean               4.392857               3.107143             2.321429
# std                0.628890               1.030616             0.818923
# min                3.000000               1.000000             1.000000
# 25%                4.000000               3.000000             2.000000
# 50%                4.000000               3.000000             2.000000
# 75%                5.000000               4.000000             3.000000
# max                5.000000               5.000000             4.000000

# %%
#Difficulty - breakdown of ranking for difficulty given by study participants after using the interface. 
#Columns broken down for Wizard, QuickFrom, WikiData, and WebProtege
difficulty =df[['Difficulty_Wizard','Difficulty_QuickForm','Difficulty_WikiData','Difficulty_WebProtege']]

difficulty_long=pd.melt(difficulty, var_name='Tool', value_name='Rating')
variable_split=difficulty_long['Tool'].str.split('_')
variable_split=variable_split.str[1]                              
difficulty_long['Tool']=variable_split
difficulty=difficulty_long[['Tool','Rating']]

#difficulty

# %%
#Frequency Table
difficulty_table=pd.crosstab(difficulty_long.Rating, difficulty_long.Tool)
difficulty_table
# Out:
# Tool    QuickForm  WebProtege  WikiData  Wizard
# Rating
# 1              23           1         0       4
# 2               5           4         2      17
# 3               0          19         3       6
# 4               0           4        23       1

# %%
#Pivot Table
difficulty_pivot=difficulty_long.pivot_table(values='Rating', columns='Tool').round(0).astype(int).mode()
columnOrder=['QuickForm', 'Wizard', 'WebProt', 'Wiki']
difficulty_pivot.reindex(columns=columnOrder)
difficulty_pivot.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_be0504f6_6fa9_11e9_b81a_ecf4bb496e51" ><thead>    <tr>        <th class="col_heading level0 col0" >QuickForm</th>        <th class="col_heading level0 col1" >WebProtege</th>        <th class="col_heading level0 col2" >WikiData</th>        <th class="col_heading level0 col3" >Wizard</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_be0504f6_6fa9_11e9_b81a_ecf4bb496e51row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_be0504f6_6fa9_11e9_b81a_ecf4bb496e51row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_be0504f6_6fa9_11e9_b81a_ecf4bb496e51row0_col2" class="data row0 col2" >4</td>
#                         <td id="T_be0504f6_6fa9_11e9_b81a_ecf4bb496e51row0_col3" class="data row0 col3" >2</td>
#             </tr>
#     </tbody></table>

# %%
#Total responses for difficulty
pd.value_counts(difficulty['Tool'])
# Out:
# QuickForm     28
# WikiData      28
# Wizard        28
# WebProtege    28
# Name: Tool, dtype: int64

# %%
#Ranked total - participants given a scale of 1-4 with 1 being easier to use & 4 harder to use.
#Scale - lower total (easier) - higher total (harder)
difficulty2 = difficulty.groupby(['Tool'], as_index=False).sum()
difficulty2.sort_values(by='Rating')
# Out:
#          Tool  Rating
# 0   QuickForm      33
# 3      Wizard      60
# 1  WebProtege      82
# 2    WikiData     105

# %%
#Summary of what respondents selected when ranking difficultyfor Wizard
#17 people ranked it as 2 withing the 1-4 difficulty scale
df.groupby('Difficulty_Wizard').size()
# Out:
# Difficulty_Wizard
# 1     4
# 2    17
# 3     6
# 4     1
# dtype: int64

# %%
#Summary of what respondents selected when ranking difficulty for WikiData
#23 people ranked it as 4 withing the 1-4 difficulty scale (hardest)
df.groupby('Difficulty_WikiData').size())
# Out:
# Difficulty_WikiData
# 2     2
# 3     3
# 4    23
# dtype: int64

# %%
#Summary of what respondents selected when ranking difficulty for WikiData
#19 people ranked it as 3 within the 1-4 difficulty scale (hardest)
df.groupby('Difficulty_WebProtege').size()
# Out:
# Difficulty_WebProtege
# 1     1
# 2     4
# 3    19
# 4     4
# dtype: int64
