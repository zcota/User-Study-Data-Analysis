# %%
import pandas as pd
import numpy as np
import os

#---------Anaylsis of responses for SESSION 3 when using ontology user interfaces----------
#wizard & Wizard_New

df = pd.read_csv('WizardComparison.csv')
#read Session 3 Comparison Questionnaire CSV file, raw data


#to read column headers use print(Wizard_Comparison.columns)

#df.describe()
#Statistical summary of User-study Session 2 responses from participants after using the software
df.describe(include=[np.object])
# Out:
#        Subject ID: Complete_Task             TermTree_Location  \
# count            9             9                             9
# unique           9             1                             2
# top           s101           Yes  In the question as in Wizard
# freq             1             9                             5
#
#                    TermTree_CleanerInterface  \
# count                                      9
# unique                                     2
# top     Beside the question as in Wizard_New
# freq                                       8
#
#                         TermTree_MoreHelpful  \
# count                                      9
# unique                                     2
# top     Beside the question as in Wizard_New
# freq                                       7
#
#                  TermTree_LocationPreference               TermTree_Display  \
# count                                      9                              9
# ...

# %%
#Wizard & Wizard New - Responses

wizard = df[['TermTree_LocationPreference', 'TermTree_DisplayPreference', 'Select_TermPreference', 'SelectTerm_Preference', 'QuestionsAnsweredFeature',
]]

wizard.describe(include=[np.object])
# Out:
#                  TermTree_LocationPreference  \
# count                                      9
# unique                                     2
# top     Beside the question as in Wizard_New
# freq                                       8
#
#                                TermTree_DisplayPreference  \
# count                                                   9
# unique                                                  2
# top     User clicks on the "i" icon to invoke the term...
# freq                                                    7
#
#                                     Select_TermPreference  \
# count                                                   9
# unique                                                  2
# top     Highlight a term to indicate selection as in W...
# freq                                                    6
#
#                                     SelectTerm_Preference  \
# count                                                   9
# ...

# %%
wizard_overall = df [['MoreDifficult','InterfacePreference', 'WizardNew_IncreaseProductivity']]

wizard_overall.describe(include=[np.object])
# Out:
#        MoreDifficult InterfacePreference WizardNew_IncreaseProductivity
# count              9                   9                              9
# unique             3                   2                              3
# top           Wizard          Wizard_New                 Somewhat agree
# freq               6                   7                              6
